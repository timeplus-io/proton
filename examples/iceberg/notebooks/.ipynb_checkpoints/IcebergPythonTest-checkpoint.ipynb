# %%
# !pip install pyiceberg[s3fs,pandas,pyarrow] boto3
# Out:
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.11/site-packages (1.41.5)
# Requirement already satisfied: pyiceberg[pandas,pyarrow,s3fs] in /opt/conda/lib/python3.11/site-packages (0.9.1)
# Requirement already satisfied: cachetools<6.0.0,>=5.5.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (5.5.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (8.1.7)
# Requirement already satisfied: fsspec>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2025.12.0)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (5.2.0)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2.0.3)
# Requirement already satisfied: pyarrow<20.0.0,>=17.0.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (19.0.1)
# Requirement already satisfied: pydantic!=2.4.0,!=2.4.1,<3.0,>=2.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2.12.5)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (3.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2.31.0)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (13.9.4)
# Requirement already satisfied: s3fs>=2023.1.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2025.12.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (2.4.0)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (1.7.3)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /opt/conda/lib/python3.11/site-packages (from pyiceberg[pandas,pyarrow,s3fs]) (9.1.2)
# Requirement already satisfied: botocore<1.42.0,>=1.41.5 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.41.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.16.0,>=0.15.0 in /opt/conda/lib/python3.11/site-packages (from boto3) (0.15.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.5->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.42.0,>=1.41.5->boto3) (2.0.7)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->pyiceberg[pandas,pyarrow,s3fs]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->pyiceberg[pandas,pyarrow,s3fs]) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.11/site-packages (from pandas<3.0.0,>=1.0.0->pyiceberg[pandas,pyarrow,s3fs]) (1.24.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic!=2.4.0,!=2.4.1,<3.0,>=2.0->pyiceberg[pandas,pyarrow,s3fs]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/conda/lib/python3.11/site-packages (from pydantic!=2.4.0,!=2.4.1,<3.0,>=2.0->pyiceberg[pandas,pyarrow,s3fs]) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.11/site-packages (from pydantic!=2.4.0,!=2.4.1,<3.0,>=2.0->pyiceberg[pandas,pyarrow,s3fs]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.11/site-packages (from pydantic!=2.4.0,!=2.4.1,<3.0,>=2.0->pyiceberg[pandas,pyarrow,s3fs]) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg[pandas,pyarrow,s3fs]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg[pandas,pyarrow,s3fs]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg[pandas,pyarrow,s3fs]) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->pyiceberg[pandas,pyarrow,s3fs]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.11/site-packages (from rich<14.0.0,>=10.11.0->pyiceberg[pandas,pyarrow,s3fs]) (2.16.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.11/site-packages (from s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (2.26.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (3.13.2)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (0.13.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (6.7.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2023.1.0->pyiceberg[pandas,pyarrow,s3fs]) (1.22.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->pyiceberg[pandas,pyarrow,s3fs]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.42.0,>=1.41.5->boto3) (1.16.0)

# %%
import os
from pyiceberg.catalog import load_catalog
import pandas as pd
import pyarrow as pa
from datetime import datetime

os.environ['PYICEBERG_DOWNCAST_NS_TIMESTAMP_TO_US_ON_WRITE'] = 'true'

# %%
# Connect to Iceberg REST Catalog
catalog = load_catalog(
    "rest",
    **{
        "uri": "http://iceberg-rest:8181",
        "s3.endpoint": "http://minio:9000",
        "s3.access-key-id": "admin",
        "s3.secret-access-key": "Password!",
        "s3.path-style-access": "true",
        "s3.region": "us-east-1" 
    }
)

print("Connected to Iceberg REST Catalog!")
print(f"Catalog properties: {catalog.properties}")
# Out:
# Connected to Iceberg REST Catalog!
# Catalog properties: {'uri': 'http://iceberg-rest:8181', 's3.endpoint': 'http://minio:9000', 's3.access-key-id': 'admin', 's3.secret-access-key': 'Password!', 's3.path-style-access': 'true', 's3.region': 'us-east-1'}

# %%
# Create Namespace (Database)
try:
    catalog.create_namespace("demo")
    print("Created namespace: demo")
except Exception as e:
    print(f"Namespace may already exist: {e}")

# List namespaces
print("\nAvailable namespaces:", catalog.list_namespaces())
# Out:
# Namespace may already exist: AlreadyExistsException: Namespace already exists: demo
#
# Available namespaces: [('demo',)]

# %%
# Drop existing table
try:
    catalog.drop_table("demo.events")
    print("Dropped existing table")
except:
    pass
# Out:
# Dropped existing table

# %%
# Create Table Schema
from pyiceberg.schema import Schema
from pyiceberg.types import (
    NestedField,
    StringType,
    DoubleType,
    TimestamptzType, # NOTE, timeplus use timestamptz for timestamp
    LongType
)

schema = Schema(
    NestedField(1, "id", LongType(), required=False),  # ← Changed to LongType and optional
    NestedField(2, "timestamp", TimestamptzType(), required=False),  # ← Made optional
    NestedField(3, "user_id", StringType(), required=False),  # ← Made optional
    NestedField(4, "event_type", StringType(), required=False),  # ← Made optional
    NestedField(5, "value", DoubleType(), required=False),
)

# Create table
try:
    table = catalog.create_table(
        identifier="demo.events",
        schema=schema,
    )
    print("Created table: demo.events")
except Exception as e:
    print(f"Table may already exist: {e}")
    table = catalog.load_table("demo.events")

print(f"\nTable schema:\n{table.schema()}")
# Out:
# Created table: demo.events
#
# Table schema:
# table {
#   1: id: optional long
#   2: timestamp: optional timestamptz
#   3: user_id: optional string
#   4: event_type: optional string
#   5: value: optional double
# }

# %%
# Write Data

data = pd.DataFrame({
    "id": [1, 2, 3, 4, 5],
    "timestamp": pd.date_range("2024-01-01", periods=5, freq="H", tz='UTC'),
    "user_id": ["user_1", "user_2", "user_1", "user_3", "user_2"],
    "event_type": ["login", "click", "purchase", "login", "click"],
    "value": [None, 10.5, 99.99, None, 25.0]
})

# Convert to PyArrow table (PyArrow will handle the precision automatically)
arrow_table = pa.Table.from_pandas(data)
print("Writing data to Iceberg table...")
table.append(arrow_table)
print("✓ Data written successfully!")
# Out:
# Iceberg does not yet support 'ns' timestamp precision. Downcasting to 'us'.
# Iceberg does not yet support 'ns' timestamp precision. Downcasting to 'us'.
# Writing data to Iceberg table...
# ✓ Data written successfully!

# %%
#  Read Data

from pyiceberg.table import TableProperties
table = catalog.load_table("demo.events")

with table.transaction() as txn:
    txn.set_properties(
        **{TableProperties.DEFAULT_NAME_MAPPING: table.metadata.schema().name_mapping.model_dump_json()}
    )

print(f"name-mapping: {table.metadata.name_mapping()}")

print("Reading data from table...")
df = table.scan().to_pandas()
print(f"\nTable has {len(df)} rows:\n")
print(df)
# Out:
# name-mapping: [
#   ([id] -> 1)
#   ([timestamp] -> 2)
#   ([user_id] -> 3)
#   ([event_type] -> 4)
#   ([value] -> 5)
# ]
# Reading data from table...
#
# Table has 5 rows:
#
#    id                 timestamp user_id event_type  value
# 0   1 2024-01-01 00:00:00+00:00  user_1      login    NaN
# 1   2 2024-01-01 01:00:00+00:00  user_2      click  10.50
# 2   3 2024-01-01 02:00:00+00:00  user_1   purchase  99.99
# 3   4 2024-01-01 03:00:00+00:00  user_3      login    NaN
# 4   5 2024-01-01 04:00:00+00:00  user_2      click  25.00

# %%
# Query with Filters
print("\n--- Filtering: event_type = 'login' ---")
df_filtered = table.scan(
    row_filter="event_type == 'login'"
).to_pandas()
print(df_filtered)

print("\n--- Filtering: value > 20 ---")
df_filtered2 = table.scan(
    row_filter="value > 20"
).to_pandas()
print(df_filtered2)
# Out:
# --- Filtering: event_type = 'login' ---
#    id                 timestamp user_id event_type  value
# 0   1 2024-01-01 00:00:00+00:00  user_1      login    NaN
# 1   4 2024-01-01 03:00:00+00:00  user_3      login    NaN
#
# --- Filtering: value > 20 ---
#    id                 timestamp user_id event_type  value
# 0   3 2024-01-01 02:00:00+00:00  user_1   purchase  99.99
# 1   5 2024-01-01 04:00:00+00:00  user_2      click  25.00

# %%
# Append More Data
new_data = pd.DataFrame({
    "id": [6, 7, 8],
    "timestamp": pd.date_range("2024-01-01 05:00:00", periods=3, freq="H", tz='UTC'),
    "user_id": ["user_1", "user_4", "user_2"],
    "event_type": ["logout", "login", "purchase"],
    "value": [None, None, 149.99]
})


# Convert to PyArrow table
arrow_new_data = pa.Table.from_pandas(new_data)

print("Appending more data...")
table.append(arrow_new_data)
print("✓ Data appended!")

# Read updated data
df_updated = table.scan().to_pandas()
print(f"\nTable now has {len(df_updated)} rows")
print(df_updated)
# Out:
# Iceberg does not yet support 'ns' timestamp precision. Downcasting to 'us'.
# Iceberg does not yet support 'ns' timestamp precision. Downcasting to 'us'.
# Appending more data...
# ✓ Data appended!
#
# Table now has 8 rows
#    id                 timestamp user_id event_type   value
# 0   6 2024-01-01 05:00:00+00:00  user_1     logout     NaN
# 1   7 2024-01-01 06:00:00+00:00  user_4      login     NaN
# 2   8 2024-01-01 07:00:00+00:00  user_2   purchase  149.99
# 3   1 2024-01-01 00:00:00+00:00  user_1      login     NaN
# 4   2 2024-01-01 01:00:00+00:00  user_2      click   10.50
# 5   3 2024-01-01 02:00:00+00:00  user_1   purchase   99.99
# 6   4 2024-01-01 03:00:00+00:00  user_3      login     NaN
# 7   5 2024-01-01 04:00:00+00:00  user_2      click   25.00

# %%
# Table History & Time Travel
print("--- Table History ---")
snapshots = table.metadata.snapshots
for snapshot in snapshots:
    print(f"Snapshot ID: {snapshot.snapshot_id}, Timestamp: {snapshot.timestamp_ms}")

# Time travel - read data as of first snapshot
if len(snapshots) >= 2:
    first_snapshot_id = snapshots[0].snapshot_id
    print(f"\n--- Time Travel to Snapshot {first_snapshot_id} ---")
    df_historical = table.scan(snapshot_id=first_snapshot_id).to_pandas()
    print(f"Historical data ({len(df_historical)} rows):")
    print(df_historical)
# Out:
# --- Table History ---
# Snapshot ID: 9007378932108796380, Timestamp: 1766862186088
# Snapshot ID: 2288071346205211959, Timestamp: 1766862193134
#
# --- Time Travel to Snapshot 9007378932108796380 ---
# Historical data (5 rows):
#    id                 timestamp user_id event_type  value
# 0   1 2024-01-01 00:00:00+00:00  user_1      login    NaN
# 1   2 2024-01-01 01:00:00+00:00  user_2      click  10.50
# 2   3 2024-01-01 02:00:00+00:00  user_1   purchase  99.99
# 3   4 2024-01-01 03:00:00+00:00  user_3      login    NaN
# 4   5 2024-01-01 04:00:00+00:00  user_2      click  25.00
